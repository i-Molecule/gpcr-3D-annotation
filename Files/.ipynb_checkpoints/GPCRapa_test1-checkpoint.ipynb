# %%
import os, sys
from Bio import SeqIO
import pandas as pd
import numpy as np
import joblib
from tqdm.notebook import tqdm
import warnings

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pdb_id = "5G5348"
#PDBFile = "/media/buianov/DATA/GPCR_challenge/APJ/dynamics/20ns/sep/name0.pdb"
#PDBFile = "/media/buianov/DATA/GA_article/New_script_for_mapping/test/3_cN_MUTS.pdb"
path_to_gpcrdb_files = "/home/madara/ilya/GPCRapa/Files/resources/Gpcrdb_files/"
dir_path = "/home/madara/ilya/Projects/Article/Case_studies/GPCR_md/5G53_48_10496/"
out_path = "/home/madara/ilya/Projects/Article/Case_studies/GPCR_md/5G53_48_10496/"
#mapping_pt = "/media/buianov/DATA/GA_article/New_script_for_mapping/APJ21_mapping.csv"
#file_name = "/media/buianov/DATA/GPCR_challenge/APJ/dynamics/20ns/sep/name0.pdb"
#pdb_id = "APJ2"
one_mod_df = "/home/madara/ilya/GPCRapa/Files/resources/mod_data/onemodal_features_dist_stats.csv"
bi_mod_df = "/home/madara/ilya/GPCRapa/Files/resources/mod_data/bimodal_features_dist_stats.csv"
model = "/home/madara/ilya/GPCRapa/Files/resources/RF_classifier_good_model_19.joblib"

# %%
def GPCRdb_mapping_for_sequence(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path):
    seq_num = []
    
    #read initial sequence
    with open(PDBFile, 'r') as pdb_file:
        with open(dir_path+"{}_structure_seq.fasta".format(pdb_id), "w") as m:
            for record in SeqIO.parse(pdb_file, 'pdb-atom'):
                print('>' + pdb_id, file = m)
                print(record.seq, file = m)
                
    #read initial numeration
    with open(PDBFile, 'r') as pdb_file:
        for line in pdb_file:
            if "ATOM" in line:
                seq_num.append(int(line[22:31]))
    seq_num = list(set(seq_num))
    #align initial sequence to GPCRdb alignment
    os.system("mafft --addfull {} --mapout {} > ns_aligned_to_db.fasta".format(dir_path+pdb_id+"_structure_seq.fasta", path_to_gpcrdb_files+"GPCRdb_alignment_honly.fasta"))
    
    #get initial position numeration according to the alogned sequence
    map_seq = pd.read_csv(dir_path+(pdb_id+"_structure_seq.fasta.map"), skiprows=1)
    map_seq["original position from pdb file"] = seq_num
    map_seq["GPCRdb_numeration"] = [pd.read_csv(path_to_gpcrdb_files+"gpcrdb_numbers_honly.csv")["Numeration"].tolist()[int(f)-1] if f  != ' -' else " -" for f in map_seq[" position in the reference alignment"].tolist()]
    map_seq["original_sequence"] = map_seq["# letter"] +map_seq["original position from pdb file"].astype("str")
    map_seq.to_csv(out_path+"{}_mapping.csv".format(pdb_id))
    
    #test for invalid mapping or mutant(N1.50: 98%, D2.50: 90%, R3.50: 95%, W4.50: 97%, P5.50: 78%, P6.50: 99%, P7.50: 88% F8x50)https://pubmed.ncbi.nlm.nih.gov/24304901/
    #conserved aa residues check
    
    check_map_df = map_seq[map_seq["GPCRdb_numeration"].isin(["1x50", "2x50", "3x50", "4x50", "5x50", "6x50", "7x50", "8x50"])].copy()
    if check_map_df[check_map_df["GPCRdb_numeration"] == "1x50"]["# letter"].tolist()[0] != "N":
        warnings.warn("The amino acid residue at position 1x50 seems not to be a canonical one (N). Please re-check the mapping results!")
    if check_map_df[check_map_df["GPCRdb_numeration"] == "2x50"]["# letter"].tolist()[0] != "D":
        warnings.warn("The amino acid residue at position 2x50 seems not to be a canonical one (D). Please re-check the mapping results!")
    if check_map_df[check_map_df["GPCRdb_numeration"] == "3x50"]["# letter"].tolist()[0] != "R":
        warnings.warn("The amino acid residue at position 3x50 seems not to be a canonical one (R). Please re-check the mapping results!")
    if check_map_df[check_map_df["GPCRdb_numeration"] == "4x50"]["# letter"].tolist()[0] != "W":
        warnings.warn("The amino acid residue at position 4x50 seems not to be a canonical one (W). Please re-check the mapping results!")
    if check_map_df[check_map_df["GPCRdb_numeration"] == "5x50"]["# letter"].tolist()[0] != "P":
        warnings.warn("The amino acid residue at position 5x50 seems not to be a canonical one (P). Please re-check the mapping results!")
    if check_map_df[check_map_df["GPCRdb_numeration"] == "6x50"]["# letter"].tolist()[0] != "P":
        warnings.warn("The amino acid residue at position 6x50 seems not to be a canonical one (P). Please re-check the mapping results!")
    if check_map_df[check_map_df["GPCRdb_numeration"] == "7x50"]["# letter"].tolist()[0] != "P":
        warnings.warn("The amino acid residue at position 7x50 seems not to be a canonical one (P). Please re-check the mapping results!")
    if check_map_df[check_map_df["GPCRdb_numeration"] == "8x50"]["# letter"].tolist()[0] != "F":
        warnings.warn("The amino acid residue at position 8x50 seems not to be a canonical one (F). Please re-check the mapping results!")
    
    print(out_path+"{}_mapping.csv".format(pdb_id))
    
    return map_seq

# %%
def calc_dist_feature_modif_no_c_id(PDBFile, map_df, pdb_id, one_mod_df, bi_mod_df):
    
    d = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
     'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N', 
     'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W', 
     'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M', 'HSD': 'X', 'HSE': 'X', 'HSP': 'X'}
    inv_d = {v: k for k, v in d.items()}
    mapping = map_df
    map_dict = {}
    for i in range(len(mapping["original_sequence"].dropna())):
        if mapping["GPCRdb_numeration"].tolist()[i] == "-":
            continue
        map_dict[str(mapping["original_sequence"].dropna().tolist()[i])] = mapping["GPCRdb_numeration"].tolist()[i]
    inv_map_dict = {v: k for k, v in map_dict.items()}
    i=0
    res_contact_list = ["1x49:7x50", "1x53:7x53", "1x53:7x54", "2x37:2x40", "2x42:4x45", "2x43:7x53", "2x45:4x50", "2x46:2x50", "2x50:3x39", "2x50:7x49", "2x57:7x42", "3x40:6x48", "3x43:6x40", "3x43:6x41", "3x43:7x49", "3x43:7x53", "3x46:6x37", "3x46:7x53", "3x46:3x50","3x49:3x50", "3x50:3x53", "3x50:6x37", "3x50:7x53", "3x51:5x57", "5x51:6x44","5x55:6x41", "5x58:6x40", "5x62:6x37", "6x40:7x49", "6x44:6x48","6x44:7x45","6x48:7x45", "7x45:7x49", "7x50:7x55","7x52:7x53", "7x53:8x50", "7x54:8x50", "7x54:8x51"]
    res_contact_tup = [(f.split(":")[0], f.split(":")[1]) for f in res_contact_list]
    #учитываем отсутствие некоторых остатков по маппингу
    res_contact_list_inc_map = [f for f in res_contact_list if f.split(":")[0] in inv_map_dict.keys() and f.split(":")[1] in inv_map_dict.keys()]
    #создаем словарь с картой контактов
    contact_dict = {}
    for item in list(set([f.split(":")[0] for f in res_contact_list_inc_map])):
            contacts = [f.split(":")[1] for f in res_contact_list_inc_map if f.split(":")[0] == item]
            contact_dict[item] = contacts
    #создаем словарь с картой контактов остатков
    contact_dict_transl = {}
    for key, value in contact_dict.items():
            contact_dict_transl[inv_map_dict[key][1:]+"_"+inv_d[inv_map_dict[key][0]]] = [inv_map_dict[f][1:]+"_"+inv_d[inv_map_dict[f][0]] for f in value]
    #создаем список остатков, которые образуют контакты
    residues_inv_in_contacts_list = []
    for item in res_contact_list_inc_map:
            residues_inv_in_contacts_list.append(inv_map_dict[item.split(":")[0]][1:]+"_"+inv_d[inv_map_dict[item.split(":")[0]][0]])
            residues_inv_in_contacts_list.append(inv_map_dict[item.split(":")[1]][1:]+"_"+inv_d[inv_map_dict[item.split(":")[1]][0]])
    residues_inv_in_contacts_list = list(set(residues_inv_in_contacts_list))

    if [f for f in res_contact_list if f not in res_contact_list_inc_map] != []:
        warnings.warn("Those features ({}) won't be computed because of missing mapping labels in mapping file. Check and recalculate mapping file or add missing mapping labels manually.")
    
    fi = open(PDBFile, 'r')
    all_lines = fi.readlines()
    fi.close()
    atom_lines = [l for l in all_lines if l[0:6] == 'ATOM  ']
    dict_coord = {} # dict to store coordinates. dict_coord[res][atom] = (x,y,z,occ)
    atomnum_2_name = {} # map atom number to atom name, in order to find N, CA, C, O
    contact_score = {} # dict to store final results. contact_score[ires][jres] = contact_score.
    for line in atom_lines:
        # retrive info from each atom line
        atom_num = int(line[6:11].strip())
        atom_name = line[12:16].replace(' ', '_')
        res_name = line[17:20]
        res_num = int(line[22:26].strip())
        #chain_id = line[21:22]
        x = float(line[30:38].strip())
        y = float(line[38:46].strip())
        z = float(line[46:54].strip())
        occ = float(line[54:60].strip())
        res = str(res_num) + '_' + res_name
        atomnum_2_name[atom_num] = atom_name
        if res_num <= 0:
            continue
        if res not in dict_coord:
            dict_coord[res] = {}
        dict_coord[res][atom_num] = (x, y, z, occ)
    mean_coords_res = {}
    for ires in residues_inv_in_contacts_list:
        atom_in_ires = dict_coord[ires].keys()
        #print(atom_in_ires)
        coords = []
        for iatom in atom_in_ires:
            iatom_name = atomnum_2_name[iatom]
            if (ires.split('_')[1]) == "GLY":
                if iatom_name in ['_N__', '_C__', '_O__']:
                        continue
                (ix, iy, iz, iocc) = dict_coord[ires][iatom]
                coords.append([ix, iy, iz])
            else:
                if iatom_name in ['_N__', '_CA_', '_C__', '_O__']:
                        continue
            #print(iatom)
                (ix, iy, iz, iocc) = dict_coord[ires][iatom]
                coords.append([ix, iy, iz])
        #print(x_coords, Average(x_coords), y_coords, Average(y_coords), z_coords, Average(z_coords))
        coords = np.array(coords)
        #print(coords)
        mean_coords = np.mean(coords, axis=0)
        mean_coords_res[ires] = mean_coords
    inter_df = []
    for ires in contact_dict_transl.keys():
        for kres in contact_dict_transl[ires]:
            ires_num = int(ires.split('_')[0].strip())
            kres_num = int(kres.split('_')[0].strip())
            if abs(ires_num - kres_num) < 5:
                icor = mean_coords_res[ires]
                kcor = mean_coords_res[kres]
                distance = np.linalg.norm(icor - kcor)
                inter_df.append({"Res_1":d[(ires.split('_')[1])]+(ires.split('_')[0]), "Res_2":d[(kres.split('_')[1])]+(kres.split('_')[0]), "{:}_{:}".format(pdb_id, PDBFile.split("/")[-1].rstrip(".pdb")): distance})
            elif abs(ires_num - kres_num) > 4:
                icor = mean_coords_res[ires]
                kcor = mean_coords_res[kres]
                distance = np.linalg.norm(icor - kcor)
                inter_df.append({"Res_1":d[(ires.split('_')[1])]+(ires.split('_')[0]), "Res_2":d[(kres.split('_')[1])]+(kres.split('_')[0]), "{:}_{:}".format(pdb_id, PDBFile.split("/")[-1].rstrip(".pdb")): distance})
    inter_df = pd.DataFrame(inter_df).drop_duplicates()
    inter_df1 = inter_df.replace(({"Res_1": map_dict}))
    inter_df2 = inter_df1.replace(({"Res_2": map_dict}))
    contacts_df = inter_df2[inter_df2[["Res_1", "Res_2"]].apply(tuple, axis=1).isin(res_contact_tup)]
    contacts_df["Interacting_residues"] = [":".join([k,f]) for k,f in zip(contacts_df["Res_1"].tolist(), contacts_df["Res_2"].tolist())]
    contacts_df = contacts_df[["Interacting_residues", "{:}_{:}".format(pdb_id, PDBFile.split("/")[-1].rstrip(".pdb"))]].T
    contacts_df = contacts_df.rename(columns=contacts_df.iloc[0]).drop(contacts_df.index[0])
    contacts_df = contacts_df[res_contact_list_inc_map]
    
    one_mod_df = pd.read_csv(one_mod_df)
    bi_mod_df = pd.read_csv(bi_mod_df)
    
    for cf, ft in zip(contacts_df.T[contacts_df.index[0]].values, contacts_df.columns):
        one_mod_feat = ["2x42:4x45", "2x43:7x53", "2x45:4x50", "3x50:6x37", "3x51:5x57", "6x44:6x48", "6x44:7x45", "6x48:7x45", "7x45:7x49"]
        if ft in one_mod_feat:
            appr_mean = one_mod_df[one_mod_df["Feature"] == ft]["approx_mean"].values[0]
            appr_std = one_mod_df[one_mod_df["Feature"] == ft]["approx_std"].values[0]
            l = 1
            while ((cf > appr_mean - appr_std*l) and (cf < appr_mean + appr_std*l)) == False:
                l+=1
            if l < 5 and l>3:
                warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
            elif l>= 5:
                warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))

        else:
            appr_mean_1 = bi_mod_df[bi_mod_df["Feature"] == ft]["approx_mean_1"].values[0]
            appr_std_1 = bi_mod_df[bi_mod_df["Feature"] == ft]["approx_std_1"].values[0]
            appr_mean_2 = bi_mod_df[bi_mod_df["Feature"] == ft]["approx_mean_2"].values[0]
            appr_std_2 = bi_mod_df[bi_mod_df["Feature"] == ft]["approx_std_2"].values[0]
            l = 1
            while (((cf > appr_mean_1 - appr_std_1*l) and (cf < appr_mean_1 + appr_std_1*l)) or ((cf > appr_mean_2 - appr_std_2*l) and (cf < appr_mean_2 + appr_std_2*l))) == False:
                 l+=1
            if l < 5 and l>3:
                warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
            elif l>= 5:
                warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))

    return contacts_df

# %%
def calc_dist_feature_modif_no_c_id_no_test(PDBFile, map_df, pdb_id, one_mod_df, bi_mod_df):
    
    d = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
     'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N', 
     'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W', 
     'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M'}#, 'HIS': 'X'}
    inv_d = {v: k for k, v in d.items()}
    mapping = map_df
    map_dict = {}
    for i in range(len(mapping["original_sequence"].dropna())):
        if mapping["GPCRdb_numeration"].tolist()[i] == "-":
            continue
        map_dict[str(mapping["original_sequence"].dropna().tolist()[i])] = mapping["GPCRdb_numeration"].tolist()[i]
    inv_map_dict = {v: k for k, v in map_dict.items()}
    i=0
    res_contact_list = ["1x49:7x50", "1x53:7x53", "1x53:7x54", "2x37:2x40", "2x42:4x45", "2x43:7x53", "2x45:4x50", "2x46:2x50", "2x50:3x39", "2x50:7x49", "2x57:7x42", "3x40:6x48", "3x43:6x40", "3x43:6x41", "3x43:7x49", "3x43:7x53", "3x46:6x37", "3x46:7x53", "3x46:3x50","3x49:3x50", "3x50:3x53", "3x50:6x37", "3x50:7x53", "3x51:5x57", "5x51:6x44","5x55:6x41", "5x58:6x40", "5x62:6x37", "6x40:7x49", "6x44:6x48","6x44:7x45","6x48:7x45", "7x45:7x49", "7x50:7x55","7x52:7x53", "7x53:8x50", "7x54:8x50", "7x54:8x51"]
    res_contact_tup = [(f.split(":")[0], f.split(":")[1]) for f in res_contact_list]
    #учитываем отсутствие некоторых остатков по маппингу
    res_contact_list_inc_map = [f for f in res_contact_list if f.split(":")[0] in inv_map_dict.keys() and f.split(":")[1] in inv_map_dict.keys()]
    #создаем словарь с картой контактов
    contact_dict = {}
    for item in list(set([f.split(":")[0] for f in res_contact_list_inc_map])):
            contacts = [f.split(":")[1] for f in res_contact_list_inc_map if f.split(":")[0] == item]
            contact_dict[item] = contacts
    #создаем словарь с картой контактов остатков
    contact_dict_transl = {}
    for key, value in contact_dict.items():
            contact_dict_transl[inv_map_dict[key][1:]+"_"+inv_d[inv_map_dict[key][0]]] = [inv_map_dict[f][1:]+"_"+inv_d[inv_map_dict[f][0]] for f in value]
    #создаем список остатков, которые образуют контакты
    residues_inv_in_contacts_list = []
    for item in res_contact_list_inc_map:
            residues_inv_in_contacts_list.append(inv_map_dict[item.split(":")[0]][1:]+"_"+inv_d[inv_map_dict[item.split(":")[0]][0]])
            residues_inv_in_contacts_list.append(inv_map_dict[item.split(":")[1]][1:]+"_"+inv_d[inv_map_dict[item.split(":")[1]][0]])
    residues_inv_in_contacts_list = list(set(residues_inv_in_contacts_list))

    if [f for f in res_contact_list if f not in res_contact_list_inc_map] != []:
        warnings.warn("Those features ({}) won't be computed because of missing mapping labels in mapping file. Check and recalculate mapping file or add missing mapping labels manually.")
    
    fi = open(PDBFile, 'r')
    all_lines = fi.readlines()
    fi.close()
    atom_lines = [l for l in all_lines if l[0:6] == 'ATOM  ']
    dict_coord = {} # dict to store coordinates. dict_coord[res][atom] = (x,y,z,occ)
    atomnum_2_name = {} # map atom number to atom name, in order to find N, CA, C, O
    contact_score = {} # dict to store final results. contact_score[ires][jres] = contact_score.
    for line in atom_lines:
        # retrive info from each atom line
        atom_num = int(line[6:11].strip())
        atom_name = line[12:16].replace(' ', '_')
        res_name = line[17:20]
        res_num = int(line[22:26].strip())
        #chain_id = line[21:22]
        x = float(line[30:38].strip())
        y = float(line[38:46].strip())
        z = float(line[46:54].strip())
        occ = float(line[54:60].strip())
        res = str(res_num) + '_' + res_name
        atomnum_2_name[atom_num] = atom_name
        if res_num <= 0:
            continue
        if res not in dict_coord:
            dict_coord[res] = {}
        dict_coord[res][atom_num] = (x, y, z, occ)
    mean_coords_res = {}
    for ires in residues_inv_in_contacts_list:
        atom_in_ires = dict_coord[ires].keys()
        #print(atom_in_ires)
        coords = []
        for iatom in atom_in_ires:
            iatom_name = atomnum_2_name[iatom]
            if (ires.split('_')[1]) == "GLY":
                if iatom_name in ['_N__', '_C__', '_O__']:
                        continue
                (ix, iy, iz, iocc) = dict_coord[ires][iatom]
                coords.append([ix, iy, iz])
            else:
                if iatom_name in ['_N__', '_CA_', '_C__', '_O__']:
                        continue
            #print(iatom)
                (ix, iy, iz, iocc) = dict_coord[ires][iatom]
                coords.append([ix, iy, iz])
        #print(x_coords, Average(x_coords), y_coords, Average(y_coords), z_coords, Average(z_coords))
        coords = np.array(coords)
        #print(coords)
        mean_coords = np.mean(coords, axis=0)
        mean_coords_res[ires] = mean_coords
    inter_df = []
    for ires in contact_dict_transl.keys():
        for kres in contact_dict_transl[ires]:
            ires_num = int(ires.split('_')[0].strip())
            kres_num = int(kres.split('_')[0].strip())
            if abs(ires_num - kres_num) < 5:
                icor = mean_coords_res[ires]
                kcor = mean_coords_res[kres]
                distance = np.linalg.norm(icor - kcor)
                inter_df.append({"Res_1":d[(ires.split('_')[1])]+(ires.split('_')[0]), "Res_2":d[(kres.split('_')[1])]+(kres.split('_')[0]), "{:}_{:}".format(pdb_id, PDBFile.split("/")[-1].rstrip(".pdb")): distance})
            elif abs(ires_num - kres_num) > 4:
                icor = mean_coords_res[ires]
                kcor = mean_coords_res[kres]
                distance = np.linalg.norm(icor - kcor)
                inter_df.append({"Res_1":d[(ires.split('_')[1])]+(ires.split('_')[0]), "Res_2":d[(kres.split('_')[1])]+(kres.split('_')[0]), "{:}_{:}".format(pdb_id, PDBFile.split("/")[-1].rstrip(".pdb")): distance})
    inter_df = pd.DataFrame(inter_df).drop_duplicates()
    inter_df1 = inter_df.replace(({"Res_1": map_dict}))
    inter_df2 = inter_df1.replace(({"Res_2": map_dict}))
    contacts_df = inter_df2[inter_df2[["Res_1", "Res_2"]].apply(tuple, axis=1).isin(res_contact_tup)]
    contacts_df["Interacting_residues"] = [":".join([k,f]) for k,f in zip(contacts_df["Res_1"].tolist(), contacts_df["Res_2"].tolist())]
    contacts_df = contacts_df[["Interacting_residues", "{:}_{:}".format(pdb_id, PDBFile.split("/")[-1].rstrip(".pdb"))]].T
    contacts_df = contacts_df.rename(columns=contacts_df.iloc[0]).drop(contacts_df.index[0])
    contacts_df = contacts_df[res_contact_list_inc_map]
    
    one_mod_df = pd.read_csv(one_mod_df)
    bi_mod_df = pd.read_csv(bi_mod_df)
    
    return contacts_df

# %%
def main(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model):
    map_df = GPCRdb_mapping_for_sequence(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path)
    res_array = calc_dist_feature_modif_no_c_id(PDBFile, map_df, pdb_id, one_mod_df, bi_mod_df).to_numpy()
    rf = joblib.load(model)
    res = rf.predict_proba(res_array)
    return res

# %%
3_10457/main(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f23a85eb1315> in <module>
# ----> 1 main(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model)
#
# NameError: name 'pdb_id' is not defined

# %% [markdown]
# # Script to calculate features

# %%
frames_dir_path = '/home/madara/ilya/GPCRmd/Class_A/Nucleotide_receptors/Adenosine_receptors/A2A_receptor/Human/48_10496_complex_with_N-ethyl-5-carboxamidoadenosine_5G53/Frames/'

# %%
def main_trajectory(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path):
    rf = joblib.load(model)
    traj_dfs = []
    i=0
    #for filenames like frame_NNN
    for PDBFile in tqdm(sorted([frames_dir_path+f for f in os.listdir(frames_dir_path)], key=lambda x: int(x.split("/")[-1].rstrip(".pdb").split("_")[1]))):
        if i == 0:
            map_df = GPCRdb_mapping_for_sequence(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path)
            res_array = calc_dist_feature_modif_no_c_id(PDBFile, map_df, pdb_id, one_mod_df, bi_mod_df).to_numpy()
            res = rf.predict_proba(res_array)
            res_arr = res
            i+=1
        else:
            res_array = calc_dist_feature_modif_no_c_id(PDBFile, map_df, pdb_id, one_mod_df, bi_mod_df).to_numpy()
            res = rf.predict_proba(res_array)
            res_arr = np.append(res_arr, res, axis = 0)
            
    return res_arr

# %%
def trajectory_df_for_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path):
    res = main_trajectory(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path)
    df_res = pd.DataFrame(res, columns = ['Inactive_prob','Active probability'])
    #df_res["label"] = pdb_id+PDBFile.split("/")[-1].rstrip(".pdb")
    df_res["frame"] = [f for f in range(0, len(df_res['Active probability']))]
    return df_res

# %%
f = trajectory_df_for_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2500.0), HTML(value='')))
# /home/madara/anaconda3/envs/modelling/lib/python3.8/site-packages/Bio/SeqIO/PdbIO.py:303: BiopythonParserWarning: 'HEADER' line not found; can't determine PDB ID.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0ac944183244> in <module>
# ----> 1 f = trajectory_df_for_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path)
#
# <ipython-input-11-4caecb05a1f7> in trajectory_df_for_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path)
#       1 def trajectory_df_for_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path):
# ----> 2     res = main_trajectory(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path)
#       3     df_res = pd.DataFrame(res, columns = ['Inactive_prob','Active probability'])
#       4     #df_res["label"] = pdb_id+PDBFile.split("/")[-1].rstrip(".pdb")
#       5     df_res["frame"] = [f for f in range(0, len(df_res['Active probability']))]
#
# <ipython-input-10-7a38433bcecb> in main_trajectory(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path)
#       6     for PDBFile in tqdm(sorted([frames_dir_path+f for f in os.listdir(frames_dir_path)], key=lambda x: int(x.split("/")[-1].rstrip(".pdb").split("_")[1]))):
#       7         if i == 0:
# ----> 8             map_df = GPCRdb_mapping_for_sequence(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path)
#       9             res_array = calc_dist_feature_modif_no_c_id(PDBFile, map_df, pdb_id, one_mod_df, bi_mod_df).to_numpy()
#      10             res = rf.predict_proba(res_array)
#
# <ipython-input-2-73d5a71945b0> in GPCRdb_mapping_for_sequence(pdb_id, PDBFile, path_to_gpcrdb_files, dir_path, out_path)
#      13         for line in pdb_file:
#      14             if "ATOM" in line:
# ---> 15                 seq_num.append(int(line[20:31]))
#      16     seq_num = list(set(seq_num))
#      17     #align initial sequence to GPCRdb alignment
#
# ValueError: invalid literal for int() with base 10: ' 0   2     '

# %%
def traj_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path, lim):
    import matplotlib.pyplot as plt
    import joblib
    import seaborn as sns
    plt.figure(figsize = (30, 10))
    df_t = trajectory_df_for_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path)
    ax1 = sns.scatterplot(data=df_t,x="frame", y="Active probability", alpha = 0.2, palette = "flare").set(ylim=(0, 1), xlim=(0, lim))
    smoothed_dfs = []
    list_sele = df_t["Active probability"].to_list()
    FIVE_split = np.array_split(list_sele, len(list_sele)//5)
    proc_data = [f.mean() for f in FIVE_split]
    df_pl = pd.DataFrame(proc_data, columns = ['Proc_data'])
    df_pl["frame"] = [f*5 for f in range(0, len(list_sele)//5)]
    smoothed_dfs.append(df_pl)
    df_s = pd.concat(smoothed_dfs)
    ax1 = sns.lineplot(data=df_s, x="frame", y="Proc_data", palette = "flare").set(ylim=(0, 1), xlim=(0, lim))
    plt.axhline(y=0.375, c="red")

# %%
traj_viz(pdb_id, path_to_gpcrdb_files, dir_path, out_path, one_mod_df, bi_mod_df, model, frames_dir_path, 500)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# /home/madara/anaconda3/envs/modelling/lib/python3.8/site-packages/Bio/SeqIO/PdbIO.py:303: BiopythonParserWarning: 'HEADER' line not found; can't determine PDB ID.
#   warnings.warn(
# /home/madara/ilya/Projects/Article/Case_studies/GPCR_md/5G53_48_10496/5G5348_mapping.csv
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 2x45:4x50 feature value 10.860861958407897. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 2x45:4x50 feature value 9.80826170004301. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 2x45:4x50 feature value 11.05220697348244. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 2x45:4x50 feature value 10.392510699183958. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 2x45:4x50 feature value 10.729047352245894. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 2x45:4x50 feature value 9.767979283644815. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.31716180660629. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.316245681706068. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.513125838112613. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.300435729569763. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.363511311902023. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.457754821415543. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.526101337373193. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.558685805693068. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.477459283930335. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.846012460472352. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.574311851803023. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.402459950405458. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.439870647732356. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.334965980250734. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.630424698894096. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.406034440380449. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.920297444539196. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.714343615556508. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.495962861372858. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.693932405347347. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.486613068356176. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.348013637075574. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.019146214492999. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.42059698746669. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.481285501678903. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.635036248673932. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.43670936278671. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.550699952195993. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.275389070465023. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.89318680644901. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.124940025438063. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.270344605338792. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.757350224314438. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.188591017277066. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.735073937528933. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.227051007187368. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.293413637545811. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.951418893391773. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.078776309079958. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.830701141140874. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.94736599684686. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.200592587400475. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.538956629338582. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.677135113636432. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.33957815112607. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.642290322742731. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.539166324039305. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.93255366439014. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 2x45:4x50. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# ...
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.321064030949884. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.996670829363513. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.011104330335833. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.772407319024191. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.041455607711525. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.048482253926542. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.545917016850852. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.360701431723697. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.996366610858532. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.304212637983003. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.919739921141565. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.409299860583864. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.980855392285553. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.860579786244317. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:136: UserWarning: Smth wrong with feature 3x46:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.427573626566595. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.843679238427828. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.839149509546253. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.409344638679732. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.355390480002045. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.973880394427947. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.254468934727493. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.4696295441098. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 14.399439342866406. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.392849018537216. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.714475318071779. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.644204457489552. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.789814617841838. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.437762091500868. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.989885796928833. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.656769365409964. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.928379280766618. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.824906620138727. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.477405363545811. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.34207182811825. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.798488425669436. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.64585402644741. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.40373434801743. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.681787449217131. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:123: UserWarning: Smth wrong with feature 3x50:6x37. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(ft))
# <ipython-input-3-d7f0e3268443>:125: UserWarning: Ambiguous 3x50:6x37 feature value 13.455157957700337. Try to check structure mapping and structure model!
#   warnings.warn('Ambiguous {} feature value {}. Try to check structure mapping and structure model!'.format(ft, cf))
