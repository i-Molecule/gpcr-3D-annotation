# %% [markdown]
# # Module run for single-pdb file

# %%
import os,sys
import pandas as pd
import numpy as np
import joblib
#import modules
import param as pr
import mapping_and_seq_mod as ms
import feature_calc_mod as fc
import apply_model_mod as aplm

# %%
#user input
pdb_id = "tttesttt"
PDBFile = "/media/buianov/DATA/Projects/gpcr-3D-annotation/Files/examples/Single_pdbs/2YDV_frame_22_act.pdb"
dir_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"# path to working directory
out_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"# path to output directory

# %%
map_df = ms.GPCRdb_mapping_for_sequence(pdb_id, PDBFile, pr.path_to_gpcrdb_files, dir_path, out_path,
                                pr.new_seq_aligned_to_GPCRdb_seq_database, pr.canonical_residues_dict,
                                pr.gpcrdb_alignment, pr.gpcrdb_numeration, pr.his_types, pr.d)
res_df = fc.calc_dist_feature_modif_no_c_id(PDBFile, map_df, pdb_id, pr.one_mod_df,
                                pr.bi_mod_df, pr.d, pr.res_contact_list, pr.one_mod_feat, 
                                pr.his_types)
aplm.model_apply(res_df, pr.model)

# %% [markdown]
# # Module run for traj

# %% [markdown]
# results in array format

# %%
import os,sys
import pandas as pd
import numpy as np
import joblib
#import modules
import trajectory_array_mod as trarr

# %%
from importlib import reload

# %%
reload(trarr)

# %%
#user input
pdb_id = "tt_test_tt"
dir_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"
out_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"
frames_dir_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/Files/examples/Trajectories/35_10386_apoform_3REY/"

# %%
trarr.main_trajectory(pdb_id,
                      pr.path_to_gpcrdb_files,
                      dir_path, out_path,
                      pr.gpcrdb_alignment,
                      pr.gpcrdb_numeration,
                      pr.one_mod_df,
                      pr.bi_mod_df,
                      pr.model,
                      frames_dir_path,
                      pr.inv_d,
                      pr.res_contact_list,
                      pr.one_mod_feat,
                      pr.new_seq_aligned_to_GPCRdb_seq_database,
                      pr.canonical_residues_dict,
                      pr.his_types,
                      pr.d)
# Out:
# ...
# /media/buianov/DATA/Projects/gpcr-3D-annotation/test/tt_test_tt_mapping.csv
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(residue_pair))
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(residue_pair))
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
# ...

# %% [markdown]
# results in pd.DataFrame() format

# %%
import os,sys
import pandas as pd
import numpy as np
import joblib
#import modules
import df_for_trj_mod as dfftrj

# %%
from importlib import reload

# %%
reload(dfftrj)
# Out:
# <module 'df_for_trj_mod' from '/media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/df_for_trj_mod.py'>

# %%
#user input
pdb_id = "tt_test_tt"
dir_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"
out_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"
frames_dir_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/Files/examples/Trajectories/35_10386_apoform_3REY/"

# %%
dfftrj.trajectory_df_for_viz(pdb_id,
                             pr.path_to_gpcrdb_files,
                             dir_path, out_path,
                             pr.gpcrdb_alignment,
                             pr.gpcrdb_numeration,
                             pr.one_mod_df, pr.bi_mod_df,
                             pr.model,
                             frames_dir_path,
                             pr.inv_d, pr.res_contact_list,
                             pr.one_mod_feat,
                             pr.new_seq_aligned_to_GPCRdb_seq_database,
                             pr.canonical_residues_dict,
                             pr.his_types, pr.d)
# Out:
# ...
# /media/buianov/DATA/Projects/gpcr-3D-annotation/test/tt_test_tt_mapping.csv
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(residue_pair))
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(residue_pair))
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
# ...

# %% [markdown]
# results visualization

# %%
import os,sys
import pandas as pd
import numpy as np
import joblib
#import modules
import res_viz_mod as rv
# Out:
# In /home/buianov/anaconda3/envs/modelling/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/buianov/anaconda3/envs/modelling/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/buianov/anaconda3/envs/modelling/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/buianov/anaconda3/envs/modelling/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# ...

# %%
from importlib import reload

# %%
reload(rv)
# Out:
# <module 'res_viz_mod' from '/media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/res_viz_mod.py'>

# %%
pdb_id = "tt_test_tt"
dir_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"
out_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/test/"
frames_dir_path = "/media/buianov/DATA/Projects/gpcr-3D-annotation/Files/examples/Trajectories/35_10386_apoform_3REY/"

# %%
rv.traj_viz(pdb_id,
            pr.path_to_gpcrdb_files,
            dir_path, out_path,
            pr.gpcrdb_alignment, pr.gpcrdb_numeration, pr.one_mod_df,
            pr.bi_mod_df, pr.model, frames_dir_path, pr.inv_d,
            pr.res_contact_list, pr.one_mod_feat,
            pr.new_seq_aligned_to_GPCRdb_seq_database, pr.canonical_residues_dict,
            pr.his_types, pr.d)
# Out:
# ...
# /media/buianov/DATA/Projects/gpcr-3D-annotation/test/tt_test_tt_mapping.csv
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(residue_pair))
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
#   warnings.warn("Smth wrong with feature {}. Check the distance between common activation pathway residues visually!".format(residue_pair))
# /media/buianov/DATA/Projects/gpcr-3D-annotation/Notebooks/feature_calc_mod.py:207: UserWarning: Smth wrong with feature 6x48:7x45. Check the distance between common activation pathway residues visually!
# ...

# %%
print(pr.his_types)
print(pr.path_to_GPCRapa)
print(pr.d)
print(pr.path_to_gpcrdb_files)
print(pr.new_seq_aligned_to_GPCRdb_seq_database)
print(pr.canonical_residues)
print(pr.canonical_residues_dict)
print(pr.gpcrdb_alignment)
print(pr.gpcrdb_numeration)
print(pr.one_mod_df)
print(pr.bi_mod_df)
print(pr.inv_d)
print(pr.one_mod_feat)
print(pr.res_contact_list)
print(pr.model)
